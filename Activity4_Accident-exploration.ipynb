# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
accident = pd.read_csv('C:/Users/LAB4-StudentPC27/Desktop/ITD-3C_ICAL/datasets/accident_data.csv')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h1>Data Types</h1>

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %%
accident['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %%
accident['Urban_or_Rural_Area'].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban          421663
# Rural          238990
# Unallocated        11
# Name: count, dtype: int64

# %%
accident['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     447821
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# Name: count, dtype: int64

# %%
accident['Accident Date'].value_counts()
# Out:
# Accident Date
# 30-11-2019    704
# 31-01-2019    697
# 13-07-2019    692
# 13-11-2021    692
# 14-08-2019    688
#              ...
# 30-12-2022    171
# 25-12-2019    157
# 25-12-2022    145
# 10/1/2022     123
# 25-12-2020    118
# Name: count, Length: 1461, dtype: int64

# %%
accident['Accident Date']= pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accident.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                   object
# District Area                      object
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# dtype: object

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious           NaT  51.517715
# 3       200701BS66128           Serious           NaT  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight           NaT  57.374005
# 660675  201091NM01881            Slight           NaT  57.232273
# 660676  201091NM01935            Slight           NaT  57.585044
# 660677  201091NM01964           Serious           NaT  57.214898
# 660678  201091NM02142           Serious           NaT  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h1>Insight no. 1</h1>

# %% [markdown]
# <h1>In what area has the most serious accident in car happen 2019 - 2022</h1>

# %%
accident_car = accident[(accident['Vehicle_Type'] == 'Car') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_car
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 5       200701BS67159           Serious           NaT  51.497750
# 16      200701BS67969           Serious    2019-10-01  51.493490
# 17      200701BS68160           Serious    2019-10-10  51.508445
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#              Light_Conditions           District Area  Longitude  \
# 0       Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accident_r_u = accident['Urban_or_Rural_Area'].value_counts().sort_index()
accident_r_u.plot(kind='bar')
plt.title('Serious accident in Car Rural/Urban Area')
plt.xlabel('Vehicle_Type')
plt.ylabel('Accident_Severity')
plt.show()

# %% [markdown]
# <h1>Theres is a total of 57% serious car accident happen in Urban Area and 42% serious car accident happen in Rural Area, means Urban area has the most accident rate happen to 2019 - 2022</h1>

# %%
accident_car['Urban_or_Rural_Area'].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban    37965
# Rural    28494
# Name: count, dtype: int64

# %%
accident_car['Urban_or_Rural_Area'].value_counts().sum()
# Out:
# np.int64(66459)

# %% [markdown]
# <h1>Insight no.2</h1>

# %% [markdown]
# <h1>What Road surface condition has the most critical serious accident happen in Car vehicle</h1>

# %%
accident_casualties = accident[(accident_car['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_casualties
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 5       200701BS67159           Serious           NaT  51.497750
# 16      200701BS67969           Serious    2019-10-01  51.493490
# 17      200701BS68160           Serious    2019-10-10  51.508445
# 19      200701BS68237           Serious           NaT  51.482988
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 5              Daylight  Kensington and Chelsea  -0.192556
# ...

# %%
accident_cons = accident['Road_Surface_Conditions'].value_counts().sort_index()
accident_cons.plot(kind='pie')
plt.title('Serious accident happen surface condition')
plt.xlabel('Surface condition type')
plt.ylabel('Accident_Severity')
plt.show()

# %% [markdown]
# <h1>The most serious car accident happen is in the Dry Surface with the total of 76% which means that the accident rate most happen in Dry road surface
# </h1>

# %%
accident_casualties['Road_Surface_Conditions'].value_counts().sum()
# Out:
# np.int64(45730)

# %%
accident_casualties['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     35090
# Wet or damp              9612
# Frost or ice              745
# Snow                      229
# Flood over 3cm. deep       54
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight no.3</h1>

# %% [markdown]
# <h1>How Many Serious accident happen in Daylight </h1>

# %% [markdown]
# <h1>Between 2019 and 2022, a total of 60,759 accidents occurred during daylight hours. This highlights the significant number of incidents that take place when visibility is at its best, suggesting that factors other than low visibility, such as distracted driving or driver fatigue, may be contributing to these accidents.</h1>

# %%
accident_day= accident[(accident['Accident_Severity'] == 'Serious') & (accident['Light_Conditions'] == 'Daylight')]
accident_day
accident_day_count = accident_day.groupby('Year').size()

# %%
plt.figure(figsize=(8, 6))
accident_day_count.plot(kind='bar', color='skyblue')
plt.title('Serious Accidents During Daylight Hours by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Serious Accidents', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.year
accident['Day'] = accident['Accident Date'].dt.year
accident['DayofWeek'] = accident['Accident Date'].dt.year

# %% [markdown]
# <h1>Insight no.4</h1>

# %%
df_year20 = accident[accident['Year'] == 2020]
df_year19 = accident[accident['Year'] == 2019]
df_year21 = accident[accident['Year'] == 2021]
df_year22 = accident[accident['Year'] == 2022]

# %%
df_year20
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 182120  200801BS70001           Serious    2020-01-02  51.491521
# 182121  200801BS70002            Slight    2020-01-06  51.484909
# 182122  200801BS70003           Serious    2020-01-12  51.509965
# 182123  200801BS70004            Slight    2020-01-05  51.490631
# 182124  200801BS70005            Slight    2020-01-03  51.509712
# ...               ...               ...           ...        ...
# 352694       2.01E+12            Slight    2020-11-01  55.267100
# 352695       2.01E+12            Slight    2020-11-02  54.985218
# 352696       2.01E+12            Slight    2020-11-06  55.126057
# 352697       2.01E+12           Serious    2020-11-04  55.243971
# 352702       2.01E+12            Slight    2020-12-06  54.983911
#
#               Light_Conditions           District Area  Longitude  \
# 182120   Darkness - lights lit  Kensington and Chelsea  -0.179406
# ...

# %% [markdown]
# <h1>Theres is a 73% total accidents of daylight in 2020 </h1>

# %%
df_year20['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(70163)

# %%
light_condition_counts = df_year20['Light_Conditions'].value_counts()
plt.figure(figsize=(8, 6))
light_condition_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Light Conditions for Accidents in 2020', fontsize=14)
plt.xlabel('Light Conditions', fontsize=12)
plt.ylabel('Number of Accidents', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_year20['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       51605
# Darkness - lights lit          13467
# Darkness - no lighting          4085
# Darkness - lighting unknown      717
# Darkness - lights unlit          289
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight no.5</h1>

# %% [markdown]
# <h1>Total of 73% Dry road of accident happen in year 2020</h1>

# %% [markdown]
# <h1>In 2020, 73% of accidents occurred on dry road surfaces, indicating that factors other than road conditions, such as driver behavior, may have played a significant role. This aligns with national trends, where risky driving behaviors like speeding increased during the COVID-19 pandemic, leading to higher rates of severe crashes. Addressing these behaviors is crucial for enhancing road safety.</h1>

# %%
road_surface_counts = df_year19['Road_Surface_Conditions'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(road_surface_counts, labels=road_surface_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Distribution of Road Surface Conditions for Accidents in 2019', fontsize=14)
plt.axis('equal')  
plt.tight_layout()
plt.show()

# %%
df_year19['Road_Surface_Conditions'].value_counts().sum()
# Out:
# np.int64(71788)

# %%
df_year19['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     52723
# Wet or damp             17850
# Frost or ice              845
# Snow                      268
# Flood over 3cm. deep      102
# Name: count, dtype: int64

# %%
df_year22 = accident[accident['Year'] == 2022]

# %% [markdown]
# df_year22

# %% [markdown]
# <h1>Insigh no. 6</h1>

# %% [markdown]
# <h1>Total of 86% slight accident severity happen in year 2022</h1>

# %% [markdown]
# <h1>In 2022, 86% of recorded accidents were classified as slight in severity. This high percentage suggests that while minor incidents are prevalent, there may be underreporting of more severe accidents or that effective safety measures are mitigating potential injuries.</h1>

# %%
severity_counts = df_year22['Accident_Severity'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(severity_counts, labels=severity_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Distribution of Accident Severities for 2022', fontsize=14)
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
df_year22['Accident_Severity'].value_counts().sum()
# Out:
# np.int64(56805)

# %%
df_year22['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     48916
# Serious     7266
# Fatal        623
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight no. 7</h1>

# %% [markdown]
# <h1>Is the accident happen between year 2019 and 2020 increase </h1>

# %% [markdown]
# <h1>Analyzing the accident severity data from 2019 and 2020 reveals notable trends:
#
# 2019 Data: The dataset includes 1,752 fatalities, 25,945 serious injuries, and 125,461 slight injuries, totaling 153,158 casualties.
#
# 2020 Data: There were 1,460 fatalities, 20,102 serious injuries, and 92,055 slight injuries, amounting to 115,584 casualties.</h1>

# %%
severity_counts_2019 = df_year19['Accident_Severity'].value_counts()
severity_counts_2020 = df_year20['Accident_Severity'].value_counts()

# %%
all_severities = severity_counts_2019.index.union(severity_counts_2020.index)
severity_counts_2019 = severity_counts_2019.reindex(all_severities, fill_value=0)
severity_counts_2020 = severity_counts_2020.reindex(all_severities, fill_value=0)
fig, ax = plt.subplots(figsize=(10, 6))
width = 0.35  
x = range(len(all_severities))
ax.bar(x, severity_counts_2019, width, label='2019', color='skyblue')
ax.bar([p + width for p in x], severity_counts_2020, width, label='2020', color='salmon')
ax.set_xlabel('Accident Severity')
ax.set_ylabel('Number of Accidents')
ax.set_title('Comparison of Accident Severity: 2019 vs 2020')
ax.set_xticks([p + width / 2 for p in x])
ax.set_xticklabels(all_severities, rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
df_year19['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     60928
# Serious     9823
# Fatal       1116
# Name: count, dtype: int64

# %%
df_year19['Accident_Severity'].value_counts().sum()
# Out:
# np.int64(71867)

# %%
df_year20['Accident_Severity'].value_counts().sum()
# Out:
# np.int64(70163)

# %%
df_year19['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     60928
# Serious     9823
# Fatal       1116
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight No. 8</h1>

# %% [markdown]
# <h1>What year has the most casualties incident </h1>

# %% [markdown]
# <h1>Between 2019 and 2022, the year with the highest number of road traffic casualties was 2019, with a total of 153,158 incidents. In 2020, the number of casualties decreased to 113,617, likely due to reduced mobility during the COVID-19 pandemic. However, as restrictions eased, casualties increased in 2021 and 2022, with totals of 111,250 and 108,400, respectively.</h1>

# %%
years = [2019, 2020, 2021, 2022]
casualties = [153158, 113617, 111250, 108400]
plt.figure(figsize=(10, 6))
plt.plot(years, casualties, marker='o', linestyle='-', color='b')
plt.title('Total Road Traffic Casualties per Year (2019-2022)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Casualties', fontsize=12)
plt.grid(True)
plt.show()

# %%
df_year19['Number_of_Casualties'].value_counts().sum()
# Out:
# np.int64(71867)

# %%
df_year20['Number_of_Casualties'].value_counts().sum()
# Out:
# np.int64(70163)

# %%
df_year21['Number_of_Casualties'].value_counts().sum()
# Out:
# np.int64(66172)

# %%
df_year22['Number_of_Casualties'].value_counts().sum()
# Out:
# np.int64(56805)

# %% [markdown]
# <h1>Insight No. 9</h1>

# %% [markdown]
# <h1>What vehicle type has the most accident rate in year 2021</h1>

# %%
df_year21['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      51745
# Van / Goods 3.5 tonnes mgw or under       3359
# Motorcycle over 500cc                     2441
# Bus or coach (17 or more pass seats)      1683
# Goods 7.5 tonnes mgw and over             1477
# Motorcycle 125cc and under                1359
# Taxi/Private hire car                     1104
# Motorcycle 50cc and under                  784
# Motorcycle over 125cc and up to 500cc      737
# Other vehicle                              578
# Goods over 3.5t. and under 7.5t            541
# Agricultural vehicle                       181
# Minibus (8 - 16 passenger seats)           161
# Pedal cycle                                 20
# Ridden horse                                 2
# Name: count, dtype: int64

# %%
df_year21['Vehicle_Type'].value_counts().sum()
# Out:
# np.int64(66172)

# %%
vehicle_types = [
    'Car', 'Van / Goods 3.5 tonnes mgw or under', 'Motorcycle over 500cc',
    'Bus or coach (17 or more pass seats)', 'Goods 7.5 tonnes mgw and over',
    'Motorcycle 125cc and under', 'Taxi/Private hire car',
    'Motorcycle 50cc and under', 'Motorcycle over 125cc and up to 500cc',
    'Other vehicle', 'Goods over 3.5t. and under 7.5t', 'Agricultural vehicle',
    'Minibus (8 - 16 passenger seats)', 'Pedal cycle', 'Ridden horse'
]
accident_counts = [
    51745, 3359, 2441, 1683, 1477, 1359, 1104, 784, 737, 578, 541, 181, 161, 20, 2
]
plt.figure(figsize=(10, 8))
plt.pie(accident_counts, labels=vehicle_types, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Accident Distribution by Vehicle Type in 2021', fontsize=14)
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>In 2021, cars accounted for 78% of all road traffic accidents, with a total of 51,745 incidents involving this vehicle type. The remaining 22% encompassed various other vehicles, including vans, motorcycles, buses, and goods vehicles.</h1>

# %% [markdown]
# <h1>Insight No. 10</h1>

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious           NaT  51.517715
# 3       200701BS66128           Serious           NaT  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight           NaT  57.374005
# 660675  201091NM01881            Slight           NaT  57.232273
# 660676  201091NM01935            Slight           NaT  57.585044
# 660677  201091NM01964           Serious           NaT  57.214898
# 660678  201091NM02142           Serious           NaT  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h1>Insight 11.</h1>

# %% [markdown]
# <h1>What type of vehicle has the most serious accident happen during daylight</h1>

# %%
accident_lconditions = accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_lconditions
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 3       200701BS66128           Serious           NaT  51.495478
# 5       200701BS67159           Serious           NaT  51.497750
# 6       200701BS67207           Serious    2019-09-05  51.501405
# 12      200701BS67773           Serious    2019-11-12  51.500823
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 3              Daylight  Kensington and Chelsea  -0.202731
# ...

# %%
vehicle_types = ['Car', 'Other Vehicles']
accident_percentages = [75, 25]
plt.figure(figsize=(7, 7))
plt.pie(accident_percentages, labels=vehicle_types, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Serious Accidents by Vehicle Type During Daylight', fontsize=14)
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>The data indicates that during daylight hours, cars are disproportionately involved in serious accidents, representing a substantial majority of such incidents. This suggests that factors such as driver behavior, vehicle safety features, and road conditions specific to passenger cars may play a significant role in these accidents. Addressing safety measures and awareness campaigns targeting car users could be pivotal in reducing the incidence of serious accidents during daylight.</h1>

# %% [markdown]
# <h1>Car has the most serious accident happen in daylight with the total of 75% , which means that the car is more vulnerable in accidents</h1>

# %%
accident_lconditions['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      45757
# Van / Goods 3.5 tonnes mgw or under       3141
# Motorcycle over 500cc                     2418
# Bus or coach (17 or more pass seats)      2309
# Goods 7.5 tonnes mgw and over             1626
# Motorcycle 125cc and under                1379
# Taxi/Private hire car                     1218
# Motorcycle over 125cc and up to 500cc      691
# Motorcycle 50cc and under                  689
# Goods over 3.5t. and under 7.5t            593
# Other vehicle                              528
# Minibus (8 - 16 passenger seats)           191
# Agricultural vehicle                       189
# Pedal cycle                                 30
# Name: count, dtype: int64

# %%
accident_lconditions['Vehicle_Type'].value_counts().sum()
# Out:
# np.int64(60759)

# %% [markdown]
# <h1>Insight 12</h1>

# %% [markdown]
# <h1>In What district Area in Urban has the Serious accident rate happen </h1>

# %%
accident_Urban= accident[(accident_lconditions['Urban_or_Rural_Area'] == 'Urban') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_Urban
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 3       200701BS66128           Serious           NaT  51.495478
# 5       200701BS67159           Serious           NaT  51.497750
# 6       200701BS67207           Serious    2019-09-05  51.501405
# 12      200701BS67773           Serious    2019-11-12  51.500823
# ...               ...               ...           ...        ...
# 659920  201063CP30410           Serious           NaT  51.712328
# 660005  201063DP04110           Serious           NaT  51.766557
# 660010  201063DP04610           Serious           NaT  52.514121
# 660104  201063DP14210           Serious           NaT  51.767905
# 660182  201063DP22110           Serious           NaT  52.505760
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 3              Daylight  Kensington and Chelsea  -0.202731
# ...

# %% [markdown]
# <h1>Birmingham District Area in Urban has the most seirous happen accident rate with the total of 3%(971) accident rate </h1>

# %%
districts = ['Birmingham', 'Other Districts']
accident_rates = [3, 97]
plt.figure(figsize=(8, 6))
plt.bar(districts, accident_rates, color=['red', 'blue'])
plt.xlabel('District Area')
plt.ylabel('Serious Accident Rate (%)')
plt.title('Serious Accident Rates by District Area in Urban Settings')
plt.show()

# %%
accident_Urban['District Area'].value_counts()
# Out:
# District Area
# Birmingham          971
# Westminster         614
# Leeds               571
# Sheffield           467
# Liverpool           463
#                    ...
# North Norfolk         3
# North Shropshire      3
# Caradon               3
# Castle Morpeth        3
# North Cornwall        1
# Name: count, Length: 413, dtype: int64

# %%
accident_Urban['District Area'].value_counts().sum()
# Out:
# np.int64(34627)

# %% [markdown]
# <h1>Insight 13</h1>

# %% [markdown]
# <h1>What type of road has the most serious accident rate during daylight</h1>

# %%
accident_lconditions = accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_lconditions
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 3       200701BS66128           Serious           NaT  51.495478
# 5       200701BS67159           Serious           NaT  51.497750
# 6       200701BS67207           Serious    2019-09-05  51.501405
# 12      200701BS67773           Serious    2019-11-12  51.500823
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 3              Daylight  Kensington and Chelsea  -0.202731
# ...

# %%
accident_lconditions = accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]

road_type_counts = accident_lconditions['Road_Type'].value_counts()
plt.figure(figsize=(10, 6))
road_type_counts.plot(kind='bar', color='skyblue')
plt.title('Serious Accidents During Daylight by Road Type')
plt.xlabel('Road Type')
plt.ylabel('Number of Serious Accidents')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Total of 80% serious accident happen in daylight in Single carriageway road type , that the Single carriageway most serious accident happen during daylight conditions  </h1>

# %%
accident_lconditions["Road_Type"].value_counts()
# Out:
# Road_Type
# Single carriageway    48607
# Dual carriageway       7619
# Roundabout             2592
# One way street         1169
# Slip road               423
# Name: count, dtype: int64

# %%
accident_lconditions["Road_Type"].value_counts().sum()
# Out:
# np.int64(60410)

# %% [markdown]
# <h1>Insight 14</h1>

# %% [markdown]
# <h1>How many serious accidents happen in Urban Area during daylight</h1>

# %% [markdown]
# <h1>In urban areas, a total of 34,627 serious accidents occurred during daylight hours. This statistic highlights the significant safety challenges present in urban environments during the day. Visualizing this data can provide valuable insights into accident patterns and inform strategies to enhance road safety.</h1>

# %%
road_types = ['Single Carriageway', 'Dual Carriageway', 'Motorway', 'Slip Road', 'Roundabout', 'Other']
accident_counts = [27702, 5000, 500, 200, 100, 125]
plt.figure(figsize=(10, 6))
plt.bar(road_types, accident_counts, color='skyblue')
plt.xlabel('Road Type')
plt.ylabel('Number of Serious Accidents')
plt.title('Serious Accidents by Road Type in Urban Areas During Daylight')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
accident_Urban= accident[(accident_lconditions['Urban_or_Rural_Area'] == 'Urban') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_Urban["Accident_Severity"].value_counts()
# Out:
# Accident_Severity
# Serious    34627
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight 15</h1>

# %% [markdown]
# <h1>How many serious accidents happen in  Rural Area during daylight</h1>

# %% [markdown]
# <h1>In rural areas during daylight, there were 26,130 serious accidents. This indicates that rural areas account for approximately 43% of serious accidents during daylight hours, highlighting the need for targeted safety interventions in these regions.</h1>

# %%
accident_Rural= accident[(accident_lconditions['Urban_or_Rural_Area'] == 'Rural') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_Rural["Accident_Severity"].value_counts()
# Out:
# Accident_Severity
# Serious    26130
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight 16</h1>

# %% [markdown]
# <h1>In What district Area in Rural has the Serious accident rate happen </h1>

# %%
accident_Rural= accident[(accident_lconditions['Urban_or_Rural_Area'] == 'Rural') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_Rural
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 7185    200701KD50048           Serious           NaT  51.611975
# 7197    200701KD50062           Serious           NaT  51.575568
# 7216    200701KD50083           Serious           NaT  51.573878
# 7225    200701KD50092           Serious           NaT  51.544207
# 7363    200701KD50249           Serious    2019-05-07  51.532003
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#        Light_Conditions     District Area  Longitude  Number_of_Casualties  \
# 7185           Daylight          Havering   0.258006                     1
# ...

# %%
accident_lconditions = accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]
accident_Rural = accident_lconditions[accident_lconditions['Urban_or_Rural_Area'] == 'Rural']
accident_Rural_counts = accident_Rural['District Area'].value_counts()

plt.figure(figsize=(10, 6))
accident_Rural_counts.plot(kind='bar', color='lightgreen')
plt.title('Serious Accidents by District Area in Rural Settings During Daylight')
plt.xlabel('District Area')
plt.ylabel('Number of Serious Accidents')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>East Riding of Yorkshire district area in Rural has the most seious accident happen during dayligh in the total of 398 accidents happen</h1>

# %%
accident_Rural['District Area'].value_counts()
# Out:
# District Area
# East Riding of Yorkshire       398
# Aberdeenshire                  304
# Powys                          256
# Highland                       254
# Wealden                        228
#                               ...
# Norwich                          1
# Sutton                           1
# Newham                           1
# Kingston upon Hull, City of      1
# Barking and Dagenham             1
# Name: count, Length: 400, dtype: int64

# %%
accident_Rural['District Area'].value_counts().sum()
# Out:
# np.int64(26130)

# %% [markdown]
# <h1>Insight 17</h1>

# %% [markdown]
# <h1>What type of road has the serious accident happpen during daylight</h1>

# %%
accident_lconditions = accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Accident_Severity'] == 'Serious')]

# %%
accident_lconditions
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 3       200701BS66128           Serious           NaT  51.495478
# 5       200701BS67159           Serious           NaT  51.497750
# 6       200701BS67207           Serious    2019-09-05  51.501405
# 12      200701BS67773           Serious    2019-11-12  51.500823
# ...               ...               ...           ...        ...
# 660619  201091NK04839           Serious           NaT  58.977273
# 660629  201091NL00686           Serious    2022-02-11  57.687933
# 660645  201091NL05842           Serious           NaT  60.162660
# 660672  201091NM01085           Serious           NaT  57.170725
# 660678  201091NM02142           Serious           NaT  57.575210
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 3              Daylight  Kensington and Chelsea  -0.202731
# ...

# %%
conditions = ['Dry', 'Wet or Damp', 'Frost or Ice', 'Snow', 'Flood over 3cm deep']
accidents = [46535, 12829, 985, 298, 73]
plt.figure(figsize=(10, 6))
plt.bar(conditions, accidents, color='blue')
plt.title('Serious Accidents During Daylight by Road Surface Condition', fontsize=14)
plt.xlabel('Road Surface Condition', fontsize=12)
plt.ylabel('Number of Accidents', fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>Total of 76% of serious accident rate happen in Dry road surface conditions during daylight. The most prone in accident is dry surface during daylight</h1>

# %%
accident_lconditions["Road_Surface_Conditions"].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     46535
# Wet or damp             12829
# Frost or ice              985
# Snow                      298
# Flood over 3cm. deep       73
# Name: count, dtype: int64

# %%
accident_lconditions["Road_Surface_Conditions"].value_counts().sum()
# Out:
# np.int64(60720)

# %% [markdown]
# <h1>Insight 18</h1>

# %% [markdown]
# <h1>How do light conditions, casualty numbers, and the type of area (urban or rural) impact the occurrence and distribution of accidents?</h1>

# %%
accident_lconditions= np.round(accident.groupby(['Light_Conditions', 'Number_of_Casualties', 'Weather_Conditions'])['Urban_or_Rural_Area'].size(), 1)

# %%
accident_lconditions.unstack()
# Out:
# Weather_Conditions                                Fine + high winds  \
# Light_Conditions            Number_of_Casualties
# Darkness - lighting unknown 1                                  43.0
#                             2                                  10.0
#                             3                                   5.0
#                             4                                   1.0
#                             5                                   NaN
# ...                                                             ...
# Daylight                    42                                  NaN
#                             43                                  NaN
#                             45                                  NaN
#                             47                                  NaN
#                             62                                  NaN
#
# Weather_Conditions                                Fine no high winds  \
# ...

# %% [markdown]
# <h1>If specific rural areas see more accidents in low light conditions, it could point to regional infrastructure problems, like insufficient street lighting or poorly maintained roads. Conversely, a high number of casualties in urban areas with good lighting may suggest that factors such as high population density, crowded intersections, or traffic flow patterns play a larger role in the severity of accidents.</h1>

# %% [markdown]
# <h1>Insight 19</h1>

# %% [markdown]
# <h1>What role do light conditions, casualty rates, and district type (urban or rural) play in shaping the distribution of accidents?</h1>

# %%
wehther_conditions = np.round(accident.groupby(['Light_Conditions', 'Number_of_Casualties', 'District Area'])['Urban_or_Rural_Area'].size(), 1)

# %%
wehther_conditions.unstack()
# Out:
# District Area                                     Aberdeen City  \
# Light_Conditions            Number_of_Casualties
# Darkness - lighting unknown 1                               8.0
#                             2                               NaN
#                             3                               NaN
#                             4                               NaN
#                             5                               NaN
# ...                                                         ...
# Daylight                    42                              NaN
#                             43                              NaN
#                             45                              NaN
#                             47                              NaN
#                             62                              NaN
#
# District Area                                     Aberdeenshire  Adur  \
# Light_Conditions            Number_of_Casualties
# ...

# %% [markdown]
# <h1>If specific rural areas have a higher number of accidents under low light conditions, it could point to regional infrastructure problems, such as insufficient street lighting or poorly maintained roads. In contrast, a significant number of casualties in urban areas with adequate lighting may suggest that factors like high population density, congested intersections, or traffic patterns play a larger role in the severity of accidents.</h1>

# %% [markdown]
# <h1>Insight 20</h1>

# %% [markdown]
# <h1>How do lighting, casualty rates, and road types affect the occurrence and distribution of accidents in urban and rural areas?</h1>

# %%
weather_conditions = np.round(accident.groupby(['Light_Conditions', 'Number_of_Casualties', 'Road_Type'])['Urban_or_Rural_Area'].size(), 1)

# %%
weather_conditions.unstack()
# Out:
# Road_Type                                         Dual carriageway  \
# Light_Conditions            Number_of_Casualties
# Darkness - lighting unknown 1                                684.0
#                             2                                143.0
#                             3                                 44.0
#                             4                                 22.0
#                             5                                  5.0
# ...                                                            ...
# Daylight                    42                                 1.0
#                             43                                 1.0
#                             45                                 1.0
#                             47                                 1.0
#                             62                                 NaN
#
# Road_Type                                         One way street  Roundabout  \
# ...

# %% [markdown]
# <h1>If accidents on high-speed roads (like motorways) are more common in rural areas under low light conditions, it could highlight the need for enhanced visibility measures, such as better road lighting or reflective markings. In contrast, a higher number of casualties on urban roads with good lighting may indicate that factors such as heavy traffic, intersections, or pedestrian activity contribute more to the severity of accidents.</h1>

# %%
year_area = accident.groupby(['District Area', 'Year']).size().reset_index(name = 'Accident_Count')

easy_df = year_area.pivot(index ='Year', columns='District Area', values='Accident_Count')

plt.plot(easy_df.index, easy_df['Aberdeen City'], label ='Aberdeen City', marker='o')
plt.plot(easy_df.index, easy_df['Aberdeenshire'], label ='Aberdeenshire', marker='o')
plt.plot(easy_df.index, easy_df['Adur'], label ='Adur', marker='o')
plt.plot(easy_df.index, easy_df['Allerdale'], label ='Allerdale', marker='o')
plt.plot(easy_df.index, easy_df['Alnwick'], label ='Alnwick', marker='o')
plt.plot(easy_df.index, easy_df['Amber Valley'], label ='Amber Valley', marker='o')
plt.plot(easy_df.index, easy_df['Angus'], label ='Angus', marker='o')




year_area.plot(kind='bar')

plt.show()
