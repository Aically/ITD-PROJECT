# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
birds = pd.read_csv('C:/Users/LAB4-StudentPC27/Desktop/ITD-3C_ICAL/datasets/penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
birds.dtypes
# Out:
# rowid                  int64
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
birds['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
birds['species'] == " Adelie"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['species'] == 'Adelie'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[(birds['species'] == 'Adelie')].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       151
# bill_depth_mm        151
# flipper_length_mm    151
# body_mass_g          151
# sex                  146
# year                 152
# dtype: int64

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')].count()
# Out:
# rowid                44
# species              44
# island               44
# bill_length_mm       44
# bill_depth_mm        44
# flipper_length_mm    44
# body_mass_g          44
# sex                  44
# year                 44
# dtype: int64

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')].count()
# Out:
# rowid                56
# species              56
# island               56
# bill_length_mm       56
# bill_depth_mm        56
# flipper_length_mm    56
# body_mass_g          56
# sex                  55
# year                 56
# dtype: int64

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen            39.1           18.7
# 1       2  Adelie  Torgersen            39.5           17.4
# 2       3  Adelie  Torgersen            40.3           18.0
# 3       4  Adelie  Torgersen             NaN            NaN
# 4       5  Adelie  Torgersen            36.7           19.3
# 5       6  Adelie  Torgersen            39.3           20.6
# 6       7  Adelie  Torgersen            38.9           17.8
# 7       8  Adelie  Torgersen            39.2           19.6
# 8       9  Adelie  Torgersen            34.1           18.1
# 9      10  Adelie  Torgersen            42.0           20.2
# 10     11  Adelie  Torgersen            37.8           17.1
# 11     12  Adelie  Torgersen            37.8           17.3
# 12     13  Adelie  Torgersen            41.1           17.6
# 13     14  Adelie  Torgersen            38.6           21.2
# 14     15  Adelie  Torgersen            34.6           21.1
# ...

# %%
birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')].count()
# Out:
# rowid                52
# species              52
# island               52
# bill_length_mm       51
# bill_depth_mm        51
# flipper_length_mm    51
# body_mass_g          51
# sex                  47
# year                 52
# dtype: int64

# %%
birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       123
# bill_depth_mm        123
# flipper_length_mm    123
# body_mass_g          123
# sex                  119
# year                 124
# dtype: int64

# %%
birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Dream')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Torgersen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Bicoe')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Dream')].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# dtype: int64

# %%
birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Torgersen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
adelie_biscoe['body_mass_g']
# Out:
# 20     3400.0
# 21     3600.0
# 22     3800.0
# 23     3950.0
# 24     3800.0
# 25     3800.0
# 26     3550.0
# 27     3200.0
# 28     3150.0
# 29     3950.0
# 50     3500.0
# 51     4300.0
# 52     3450.0
# 53     4050.0
# 54     2900.0
# 55     3700.0
# 56     3550.0
# 57     3800.0
# 58     2850.0
# 59     3750.0
# 60     3150.0
# 61     4400.0
# 62     3600.0
# 63     4050.0
# 64     2850.0
# 65     3950.0
# 66     3350.0
# 67     4100.0
# 100    3725.0
# 101    4725.0
# 102    3075.0
# 103    4250.0
# 104    2925.0
# 105    3550.0
# 106    3750.0
# 107    3900.0
# 108    3175.0
# 109    4775.0
# 110    3825.0
# 111    4600.0
# 112    3200.0
# 113    4275.0
# 114    3900.0
# 115    4075.0
# Name: body_mass_g, dtype: float64

# %%
adelie_biscoe['body_mass_g'].mean()
# Out:
# np.float64(3709.659090909091)

# %%
np.round(adelie_biscoe['body_mass_g'].mean(), 1)
# Out:
# np.float64(3709.7)

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
adelie_dream['body_mass_g'].mean()
# Out:
# np.float64(3688.3928571428573)

# %%
np.round(adelie_dream['body_mass_g'].mean(), 1)
# Out:
# np.float64(3688.4)

# %%
adelie_torg= birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
adelie_torg['body_mass_g'].mean()
# Out:
# np.float64(3706.372549019608)

# %%
np.round(adelie_torg['body_mass_g'].mean(), 1)
# Out:
# np.float64(3706.4)

# %%
gentoo_biscoe=[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')]

# %%
adelie_biscoe= birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
birds['wkilo'] = np.round(birds['body_mass_g']/1000,1)

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen            39.1           18.7
# 1       2     Adelie  Torgersen            39.5           17.4
# 2       3     Adelie  Torgersen            40.3           18.0
# 3       4     Adelie  Torgersen             NaN            NaN
# 4       5     Adelie  Torgersen            36.7           19.3
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream            55.8           19.8
# 340   341  Chinstrap      Dream            43.5           18.1
# 341   342  Chinstrap      Dream            49.6           18.2
# 342   343  Chinstrap      Dream            50.8           19.0
# 343   344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  wkilo
# 0                181.0       3750.0    male  2007    3.8
# 1                186.0       3800.0  female  2007    3.8
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
#  9   wkilo              342 non-null    float64
# dtypes: category(1), float64(5), int64(1), object(3)
# memory usage: 35.8+ KB

# %%
birds['wkilo'].mean()
# Out:
# np.float64(4.202046783625731)

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
adelie_dream['wkilo'].mean()
# Out:
# np.float64(3.6910714285714286)

# %%
np.round(adelie_dream['wkilo'].mean() , 1)
# Out:
# np.float64(3.7)

# %%
adelie_torg= birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
adelie_torg['wkilo'].mean()
# Out:
# np.float64(3.7019607843137257)

# %%
np.round(adelie_torg['wkilo'].mean(),1)
# Out:
# np.float64(3.7)

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
adelie_biscoe['wkilo'].mean()
# Out:
# np.float64(3.715909090909091)

# %%
np.round(adelie_biscoe['wkilo'].mean(),1)
# Out:
# np.float64(3.7)

# %%
birds_agg = birds.groupby(['species', 'island' , 'sex']).count()

# %%
birds_agg
# Out:
#                             rowid  bill_length_mm  bill_depth_mm  \
# species   island    sex
# Adelie    Biscoe    female     22              22             22
#                     male       22              22             22
#           Dream     female     27              27             27
#                     male       28              28             28
#           Torgersen female     24              24             24
#                     male       23              23             23
# Chinstrap Dream     female     34              34             34
#                     male       34              34             34
# Gentoo    Biscoe    female     58              58             58
#                     male       61              61             61
#
#                             flipper_length_mm  body_mass_g  year  wkilo
# species   island    sex
# Adelie    Biscoe    female                 22           22    22     22
# ...

# %%
birds_ar = birds.groupby(['species', 'year' , 'sex']).size()

# %%
birds_ar
# Out:
# species    year  sex
# Adelie     2007  female    22
#                  male      22
#            2008  female    25
#                  male      25
#            2009  female    26
#                  male      26
# Chinstrap  2007  female    13
#                  male      13
#            2008  female     9
#                  male       9
#            2009  female    12
#                  male      12
# Gentoo     2007  female    16
#                  male      17
#            2008  female    22
#                  male      23
#            2009  female    20
#                  male      21
# dtype: int64

# %%
birds_ar.unstack()
# Out:
# sex             female  male
# species   year
# Adelie    2007      22    22
#           2008      25    25
#           2009      26    26
# Chinstrap 2007      13    13
#           2008       9     9
#           2009      12    12
# Gentoo    2007      16    17
#           2008      22    23
#           2009      20    21

# %% [markdown]
# <h1>Insight No. 8</h1>
# <h3>The Highest number of male adelie penguins recorded was in year 2007</h3>

# %% [markdown]
# <h1>How to use grouby function</h1>
# <ul>
# <li>Name of the group variable</li>
# <li>call the reference</li>
# <li>columns ti combine</li>
# <li> aggregate function</li>
# </ul>

# %% [markdown]
# <h1> Question No.9</h1>

# %%
weight_sex = birds.groupby(['species','sex','wkilo']).size()

# %%
weight_sex
# Out:
# species  sex     wkilo
# Adelie   female  2.8       2
#                  2.9       4
#                  3.0       6
#                  3.1       2
#                  3.2      12
#                           ..
# Gentoo   male    5.6      11
#                  5.7       5
#                  5.8       6
#                  6.0       5
#                  6.3       1
# Length: 80, dtype: int64

# %%
weight_sex = np.round(birds.groupby(['species','sex',])['wkilo'].mean(),1)

# %%
weight_sex
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.5
# Name: wkilo, dtype: float64

# %%
weight_sex.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.5

# %% [markdown]
# <h1>Question 10</h1>
# <h3>What year has the highest recorded weight for male and female</h3>

# %%
weight_sex = np.round(birds.groupby(['species','sex','year'])['wkilo'].mean(),1)

# %%
weight_sex
# Out:
# species    sex     year
# Adelie     female  2007    3.4
#                    2008    3.4
#                    2009    3.3
#            male    2007    4.0
#                    2008    4.1
#                    2009    4.0
# Chinstrap  female  2007    3.6
#                    2008    3.5
#                    2009    3.5
#            male    2007    3.8
#                    2008    4.1
#                    2009    3.9
# Gentoo     female  2007    4.6
#                    2008    4.6
#                    2009    4.8
#            male    2007    5.5
#                    2008    5.4
#                    2009    5.5
# Name: wkilo, dtype: float64

# %%
weight_sex.unstack()
# Out:
# year              2007  2008  2009
# species   sex
# Adelie    female   3.4   3.4   3.3
#           male     4.0   4.1   4.0
# Chinstrap female   3.6   3.5   3.5
#           male     3.8   4.1   3.9
# Gentoo    female   4.6   4.6   4.8
#           male     5.5   5.4   5.5

# %% [markdown]
# <h1>Question 11</h1>
# <h3>Correlation between bill lenght and bill depth</h3>

# %% [markdown]
# <h1> P VALUE in STATISTICS</h1>

# %% [markdown]
# <h1>anything above .5 means the two values has a string correlation</h1>
# <h1>anything less than .5 meaning less or no correlation</h1>

# %% [markdown]
# <h1>Requirements for Correlation</h1>
# <ul>
#     <li>Naming the variable</li>
#     <li>first column to test</li>
#     <li>.corr Function</li>
#     <li>second column to test</li>
#
# </ul>

# %% [markdown]
# <h1>Statistical Treatment</h1>
# <h1>Pandas Default - Pearson R Correlation</h1>
# <h1>Used for measuring correlation between quantitive Data</h1>

# %%
birds.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year       wkilo
# count   344.000000  342.000000
# mean   2008.029070    4.202047
# std       0.818356    0.803089
# min    2007.000000    2.700000
# 25%    2007.000000    3.600000
# 50%    2008.000000    4.000000
# 75%    2009.000000    4.800000
# max    2009.000000    6.300000

# %% [markdown]
# <h1>There is no correlation between bill length and bill depth</h1>

# %%
b_lenght_depth = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
b_lenght_depth
# Out:
# np.float64(-0.23505287035553257)

# %% [markdown]
# <h1>Insight 12</h1>
# <h1>Correlation between bill length and flipper length</h1>
# <h1>There is a correlation between bill length and flipper length</h1>

# %%
b_lenght_depth = birds['bill_length_mm'].corr(birds['flipper_length_mm'])

# %%
b_lenght_depth
# Out:
# np.float64(0.6561813407464278)

# %% [markdown]
# <h1>Insight 13</h1>
# <h1>Correlation between body mass and flipper length</h1>
# <h1>There is a correlation between body mass and flipper length</h1>

# %%
b_body_g = birds['body_mass_g'].corr(birds['flipper_length_mm'])

# %%
b_body_g
# Out:
# np.float64(0.8712017673060113)

# %% [markdown]
# <h1>Insight 14</h1>
# <h1>Correlation between bill depth and body mass</h1>
# <h1>There is no correlation between bill depth and body mass</h1>

# %%
b_lenght_depth = birds['bill_depth_mm'].corr(birds['body_mass_g'])

# %%
b_lenght_depth
# Out:
# np.float64(-0.47191562118606645)

# %% [markdown]
# <h1>Use of One Way Anova</h1>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC27\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h1>testing  correlation between body mass and sex</h1>

# %%
birds[birds['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.0
# 5      3650.0
# 7      4675.0
# 13     3800.0
# 14     4400.0
#         ...
# 334    3800.0
# 336    3950.0
# 339    4000.0
# 341    3775.0
# 342    4100.0
# Name: body_mass_g, Length: 168, dtype: float64

# %% [markdown]
# <h1>Insight 15: Correlation between sex and body mass</h1>

# %% [markdown]
# <h1>There is less correlation between sex and body mass</h1>

# %%
f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['body_mass_g'],birds[birds['sex'] == 'female']['body_mass_g'])
p_value
# Out:
# np.float64(4.897246751596225e-16)

# %% [markdown]
# <h1>Insight 16: Correlation between sex and body mass</h1>

# %% [markdown]
# <h1>There is no correlation between sex and body mass</h1>

# %%
f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['flipper_length_mm'],birds[birds['sex'] == 'female']['flipper_length_mm'])
p_value
# Out:
# np.float64(2.3910970925541695e-06)
